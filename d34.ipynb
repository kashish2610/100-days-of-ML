# %%
import numpy as np
import pandas as pd

# %%
date= pd.read_csv('/content/orders.csv')
time=pd.read_csv('/content/messages.csv')

# %%
date.head(2)
# Out:
#          date  product_id  city_id  orders
# 0  2019-12-10        5628       25       3
# 1  2018-08-15        3646       14     157

# %%
time.head(3)
# Out:
#                   date                                               msg
# 0  2013-12-15 00:50:00                          ищу на сегодня мужика 37
# 1  2014-04-29 23:40:00  ПАРЕНЬ БИ ИЩЕТ ДРУГА СЕЙЧАС!! СМС ММС 0955532826
# 2  2012-12-30 00:21:00          Днепр.м 43 позн.с д/ж *.о  067.16.34.576

# %%
time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    1000 non-null   object
#  1   msg     1000 non-null   object
# dtypes: object(2)
# memory usage: 15.8+ KB

# %% [markdown]
# # Dates

# %%
date['date']=pd.to_datetime(date['date'])

# %%
date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        1000 non-null   datetime64[ns]
#  1   product_id  1000 non-null   int64
#  2   city_id     1000 non-null   int64
#  3   orders      1000 non-null   int64
# dtypes: datetime64[ns](1), int64(3)
# memory usage: 31.4 KB

# %%
date['date_year']=date['date'].dt.year
date.head(3)
# Out:
#         date  product_id  city_id  orders  date_year
# 0 2019-12-10        5628       25       3       2019
# 1 2018-08-15        3646       14     157       2018
# 2 2018-10-23        1859       25       1       2018

# %%
date['date_month']=date['date'].dt.month
date.head(3)
# Out:
#         date  product_id  city_id  orders  date_year  date_month
# 0 2019-12-10        5628       25       3       2019          12
# 1 2018-08-15        3646       14     157       2018           8
# 2 2018-10-23        1859       25       1       2018          10

# %%
date['date_month']=date['date'].dt.month_name()

# %%
date.head(3)
# Out:
#         date  product_id  city_id  orders  date_year date_month
# 0 2019-12-10        5628       25       3       2019   December
# 1 2018-08-15        3646       14     157       2018     August
# 2 2018-10-23        1859       25       1       2018    October

# %%
date['date_day']=date['date'].dt.day

# %%
date['date_day']=date['date'].dt.dayofweek

# %%
date['date_day']=date['date'].dt.day_name()

# %%
date.head(3)
# Out:
#         date  product_id  city_id  orders  date_year date_month   date_day
# 0 2019-12-10        5628       25       3       2019   December    Tuesday
# 1 2018-08-15        3646       14     157       2018     August  Wednesday
# 2 2018-10-23        1859       25       1       2018    October    Tuesday

# %%
# @title Default title text
date['weekend']=np.where(date['date_day'].isin(['Sunday','Saturday']),1,0)

# %%
date
# Out:
#           date  product_id  city_id  orders  date_year date_month   date_day  \
# 0   2019-12-10        5628       25       3       2019   December    Tuesday
# 1   2018-08-15        3646       14     157       2018     August  Wednesday
# 2   2018-10-23        1859       25       1       2018    October    Tuesday
# 3   2019-08-17        7292       25       1       2019     August   Saturday
# 4   2019-01-06        4344       25       3       2019    January     Sunday
# ..         ...         ...      ...     ...        ...        ...        ...
# 995 2018-10-08         255       13       1       2018    October     Monday
# 996 2018-12-06        5521        7       1       2018   December   Thursday
# 997 2019-05-07         487       26      14       2019        May    Tuesday
# 998 2019-03-03        1503       21       2       2019      March     Sunday
# 999 2019-10-15        6371        7      22       2019    October    Tuesday
#
#      weekend
# 0          0
# 1          0
# ...

# %%
date['date_quater']=date['date'].dt.quarter

# %%
date
# Out:
#           date  product_id  city_id  orders  date_year date_month   date_day  \
# 0   2019-12-10        5628       25       3       2019   December    Tuesday
# 1   2018-08-15        3646       14     157       2018     August  Wednesday
# 2   2018-10-23        1859       25       1       2018    October    Tuesday
# 3   2019-08-17        7292       25       1       2019     August   Saturday
# 4   2019-01-06        4344       25       3       2019    January     Sunday
# ..         ...         ...      ...     ...        ...        ...        ...
# 995 2018-10-08         255       13       1       2018    October     Monday
# 996 2018-12-06        5521        7       1       2018   December   Thursday
# 997 2019-05-07         487       26      14       2019        May    Tuesday
# 998 2019-03-03        1503       21       2       2019      March     Sunday
# 999 2019-10-15        6371        7      22       2019    October    Tuesday
#
#      weekend  date_week  date_quater
# ...

# %%
date['sem']=np.where(date['date_quater'].isin([1,2]),1,2)

# %%
date
# Out:
#           date  product_id  city_id  orders  date_year date_month   date_day  \
# 0   2019-12-10        5628       25       3       2019   December    Tuesday
# 1   2018-08-15        3646       14     157       2018     August  Wednesday
# 2   2018-10-23        1859       25       1       2018    October    Tuesday
# 3   2019-08-17        7292       25       1       2019     August   Saturday
# 4   2019-01-06        4344       25       3       2019    January     Sunday
# ..         ...         ...      ...     ...        ...        ...        ...
# 995 2018-10-08         255       13       1       2018    October     Monday
# 996 2018-12-06        5521        7       1       2018   December   Thursday
# 997 2019-05-07         487       26      14       2019        May    Tuesday
# 998 2019-03-03        1503       21       2       2019      March     Sunday
# 999 2019-10-15        6371        7      22       2019    October    Tuesday
#
#      weekend  date_week  date_quater  sem
# ...

# %%
# @title Extract time elapsed between date
import datetime
today= datetime.datetime.today()
today
# Out:
# datetime.datetime(2025, 6, 16, 8, 25, 39, 813665)

# %%
today - date['date']
# Out:
# 0     2015 days 08:25:39.813665
# 1     2497 days 08:25:39.813665
# 2     2428 days 08:25:39.813665
# 3     2130 days 08:25:39.813665
# 4     2353 days 08:25:39.813665
#                  ...
# 995   2443 days 08:25:39.813665
# 996   2384 days 08:25:39.813665
# 997   2232 days 08:25:39.813665
# 998   2297 days 08:25:39.813665
# 999   2071 days 08:25:39.813665
# Name: date, Length: 1000, dtype: timedelta64[ns]

# %%
(today - date['date']).dt.days
# Out:
# 0      2015
# 1      2497
# 2      2428
# 3      2130
# 4      2353
#        ...
# 995    2443
# 996    2384
# 997    2232
# 998    2297
# 999    2071
# Name: date, Length: 1000, dtype: int64

# %%
np.round((today -date['date']) / np.timedelta64(30,'D'),0)
# Out:
# 0      67.0
# 1      83.0
# 2      81.0
# 3      71.0
# 4      78.0
#        ...
# 995    81.0
# 996    79.0
# 997    74.0
# 998    77.0
# 999    69.0
# Name: date, Length: 1000, dtype: float64

# %% [markdown]
# # time

# %%
time['date']=pd.to_datetime(time['date'])

# %%
time['hour']=time['date'].dt.hour
time['min']=time['date'].dt.minute
time['sec']=time['date'].dt.second

# %%
time
# Out:
#                    date                                                msg  \
# 0   2013-12-15 00:50:00                           ищу на сегодня мужика 37
# 1   2014-04-29 23:40:00   ПАРЕНЬ БИ ИЩЕТ ДРУГА СЕЙЧАС!! СМС ММС 0955532826
# 2   2012-12-30 00:21:00           Днепр.м 43 позн.с д/ж *.о  067.16.34.576
# 3   2014-11-28 00:31:00  КИЕВ ИЩУ Д/Ж ДО 45 МНЕ СЕЙЧАС СКУЧНО 093 629 9...
# 4   2013-10-26 23:11:00    Зая я тебя никогда не обижу  люблю тебя!)  Даше
# ..                  ...                                                ...
# 995 2012-03-16 00:50:00     ПАРЕНЬ СДЕЛАЕТ  МАССАЖ ЖЕНЩИНАМ -066-877-32-44
# 996 2014-01-23 23:14:00            сельский п 23 ищу девушку для отношений
# 997 2012-10-15 23:37:00  Д+Д ДЛЯ серьезных отношений. Мой номер 093-156...
# 998 2012-06-21 23:34:00  7 ДНЕПР М.34 ПОЗ.С Д/Ж ДЛЯ ВСТРЕЧ.Т.098 809 15 14
# 999 2014-06-19 23:25:00          Парень поласкает девушке...  т.0662035584
#
#      hour  min  sec
# 0       0   50    0
# 1      23   40    0
# ...

# %%
today - time['date']
# Out:
# 0     4201 days 07:35:39.813665
# 1     4065 days 08:45:39.813665
# 2     4551 days 08:04:39.813665
# 3     3853 days 07:54:39.813665
# 4     4250 days 09:14:39.813665
#                  ...
# 995   4840 days 07:35:39.813665
# 996   4161 days 09:11:39.813665
# 997   4626 days 08:48:39.813665
# 998   4742 days 08:51:39.813665
# 999   4014 days 09:00:39.813665
# Name: date, Length: 1000, dtype: timedelta64[ns]

# %%
# @title sec
(today - time['date'])/np.timedelta64(1,'s')
# Out:
# 0      3.629937e+08
# 1      3.512475e+08
# 2      3.932355e+08
# 3      3.329277e+08
# 4      3.672333e+08
#            ...
# 995    4.182033e+08
# 996    3.595435e+08
# 997    3.997181e+08
# 998    4.097407e+08
# 999    3.468420e+08
# Name: date, Length: 1000, dtype: float64

# %%
# @title min
(today - time['date'])/np.timedelta64(1,'m')
# Out:
# 0      6.049896e+06
# 1      5.854126e+06
# 2      6.553925e+06
# 3      5.548795e+06
# 4      6.120555e+06
#            ...
# 995    6.970056e+06
# 996    5.992392e+06
# 997    6.661969e+06
# 998    6.829012e+06
# 999    5.780701e+06
# Name: date, Length: 1000, dtype: float64
