# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('/content/titanic.csv')

# %%
df
# Out:
#     Cabin            Ticket number  Survived
# 0     NaN         A/5 21171      5         0
# 1     C85          PC 17599      3         1
# 2     NaN  STON/O2. 3101282      6         1
# 3    C123            113803      3         1
# 4     NaN            373450      A         0
# ..    ...               ...    ...       ...
# 886   NaN            211536      3         0
# 887   B42            112053      3         1
# 888   NaN        W./C. 6607      1         0
# 889  C148            111369      2         1
# 890   NaN            370376      3         0
#
# [891 rows x 4 columns]

# %% [markdown]
# # number

# %%
fig=df['number'].value_counts().plot(kind='bar')

# %%
df['number_num']=pd.to_numeric(df['number'],errors='coerce',downcast='integer')

# %%
df['number_cat']=np.where(df['number_num'].isnull(),df['number'],np.nan)

# %%
df
# Out:
#     Cabin            Ticket number  Survived  number_num number_cat
# 0     NaN         A/5 21171      5         0         5.0        NaN
# 1     C85          PC 17599      3         1         3.0        NaN
# 2     NaN  STON/O2. 3101282      6         1         6.0        NaN
# 3    C123            113803      3         1         3.0        NaN
# 4     NaN            373450      A         0         NaN          A
# ..    ...               ...    ...       ...         ...        ...
# 886   NaN            211536      3         0         3.0        NaN
# 887   B42            112053      3         1         3.0        NaN
# 888   NaN        W./C. 6607      1         0         1.0        NaN
# 889  C148            111369      2         1         2.0        NaN
# 890   NaN            370376      3         0         3.0        NaN
#
# [891 rows x 6 columns]

# %% [markdown]
# # cabin

# %%
 df['Cabin_num']=df['Cabin'].str.extract('(\d+)') # capture numeric values
df['cabin_cat']=df['Cabin'].str[0]

# %%
df
# Out:
#     Cabin            Ticket number  Survived  number_num number_cat Cabin_num  \
# 0     NaN         A/5 21171      5         0         5.0        NaN       NaN
# 1     C85          PC 17599      3         1         3.0        NaN        85
# 2     NaN  STON/O2. 3101282      6         1         6.0        NaN       NaN
# 3    C123            113803      3         1         3.0        NaN       123
# 4     NaN            373450      A         0         NaN          A       NaN
# ..    ...               ...    ...       ...         ...        ...       ...
# 886   NaN            211536      3         0         3.0        NaN       NaN
# 887   B42            112053      3         1         3.0        NaN        42
# 888   NaN        W./C. 6607      1         0         1.0        NaN       NaN
# 889  C148            111369      2         1         2.0        NaN       148
# 890   NaN            370376      3         0         3.0        NaN       NaN
#
#     cabin_cat
# 0         NaN
# ...

# %%
# extract last bit of ticket as no.
df['tic_num']=df['Ticket'].apply(lambda s: s.split()[-1])
df['tic_num']=pd.to_numeric(df['tic_num'],errors='coerce',downcast='integer')
# extract 1st part of tic as cat
df['tic_cat']=df['Ticket'].apply(lambda s: s.split()[0])
df['tic_cat']=np.where(df['tic_cat'].str.isdigit(),df['tic_cat'],np.nan)

# %%
df
# Out:
#     Cabin            Ticket number  Survived  number_num number_cat Cabin_num  \
# 0     NaN         A/5 21171      5         0         5.0        NaN       NaN
# 1     C85          PC 17599      3         1         3.0        NaN        85
# 2     NaN  STON/O2. 3101282      6         1         6.0        NaN       NaN
# 3    C123            113803      3         1         3.0        NaN       123
# 4     NaN            373450      A         0         NaN          A       NaN
# ..    ...               ...    ...       ...         ...        ...       ...
# 886   NaN            211536      3         0         3.0        NaN       NaN
# 887   B42            112053      3         1         3.0        NaN        42
# 888   NaN        W./C. 6607      1         0         1.0        NaN       NaN
# 889  C148            111369      2         1         2.0        NaN       148
# 890   NaN            370376      3         0         3.0        NaN       NaN
#
#     cabin_cat    tic_num tic_cat
# ...
